# %% [markdown]
# max r2, min rmse
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.r2_score.html

# %% [markdown]
# columns:
#
# Sipariş Numarası: Her siparişe ait unique ID.
# Sipariş Satırı: Aynı “Sipariş Numarası” içinde sipariş edilen ürünlerin satır numarası.  (Aynı siparişe ilişkin farklı ürünleri belirtilen satır numarası olarak değerlendirilebilir)
# Sipariş Tipi: Sevk edilecek siparişin tipi.
# Malzeme Numarası: Ürüne ait unique ID.
# Sipariş Edilen Miktar: Ürüne ait sipariş miktarı.
# Sku Plt. Standartı: Her ürüne ait bir palete yüklenebilecek ürün miktarı. (ürünün boyutlarına göre değişkenlik gösterir)
# Müşteri No: Siparişin sevk edileceği müşteriye ait unique ID.
# Sipariş Tarihi: Siparişin DHL depo yönetim sistemindeki tarihi. (Yıl – Ay- Gün formatında)

# %% [markdown]
# additional data:
#
# holidays data?

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate, KFold, GridSearchCV
from sklearn.compose import ColumnTransformer
from xgboost import XGBRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train_set.csv', parse_dates=['Sipariş Tarihi'])
df.head()
# Out:
#    Sipariş Numarası  Sipariş Satırı         Sipariş Tipi Malzeme Numarası  \
# 0          72616887               1  Müşteri Siparişleri         61001960
# 1          72616888               1  Müşteri Siparişleri         61000066
# 2          72616888               2  Müşteri Siparişleri         61001960
# 3          72616889               1  Müşteri Siparişleri         61000066
# 4          72616889               2  Müşteri Siparişleri         61001960
#
#    Sipariş Edilen Miktar  Sku Plt. Standartı Müşteri No Sipariş Tarihi
# 0                     60                 228    C-10008     2020-01-02
# 1                     25                  96    C-10185     2020-01-02
# 2                     50                 228    C-10185     2020-01-02
# 3                     40                  96    C-10188     2020-01-02
# 4                     20                 228    C-10188     2020-01-02

# %%
df.shape
# Out:
# (276753, 8)

# %%
df.columns = ['order_num', 'order_item', 'order_type', 'material_num', 'order_amount', 'pallet_std', 'customer_num', 'order_date']

# %%
df = df.groupby(['order_num', 'material_num']).agg({'order_item':'max', 'order_type':'max', 'order_amount':'sum', 'pallet_std':'min',
                                               'customer_num':'max', 'order_date':'max'}).reset_index()

# %%
df.sort_values(by=['order_num'], inplace=True)

# %%
print('number of unique order: ', len(df['order_num'].unique()))
print('number of unique customer: ', len(df['customer_num'].unique()))
print('average order by customers: ', int(len(df['order_num'].unique())/len(df['customer_num'].unique())))
print('number of unique order types: ', len(df['order_type'].unique()))
print('number of unique materials: ', len(df['material_num'].unique()))
print('number of unique pallet types: ', len(df['pallet_std'].unique()))
# Out:
# number of unique order:  37085
# number of unique customer:  283
# average order by customers:  131
# number of unique order types:  3
# number of unique materials:  466
# number of unique pallet types:  90

# %%
df.describe()
# Out:
#           order_num     order_item   order_amount     pallet_std
# count  2.566770e+05  256677.000000  256677.000000  256677.000000
# mean   7.264149e+07      86.211055      29.495635     128.215189
# std    1.411038e+04     850.232238     147.388895      78.267588
# min    7.261689e+07       1.000000       1.000000       1.000000
# 25%    7.262930e+07       3.000000       1.000000      72.000000
# 50%    7.264187e+07       8.000000       4.000000      96.000000
# 75%    7.265357e+07      20.000000      19.000000     185.000000
# max    7.266620e+07    9999.000000   12210.000000     650.000000

# %%
import phik
phi_corr = df.phik_matrix()
phi_corr[phi_corr.abs()>0.5]
# Out:
# interval columns not set, guessing: ['order_num', 'order_item', 'order_amount', 'pallet_std']
#               order_num  material_num  order_item  order_type  order_amount  \
# order_num      1.000000      0.554811         NaN         NaN           NaN
# material_num   0.554811      1.000000         1.0    0.777909      0.684437
# order_item          NaN      1.000000         1.0         NaN           NaN
# order_type          NaN      0.777909         NaN    1.000000           NaN
# order_amount        NaN      0.684437         NaN         NaN      1.000000
# pallet_std          NaN      0.999994         NaN         NaN           NaN
# customer_num        NaN      0.908309         NaN    1.000000           NaN
# order_date     0.999918      0.835337         NaN         NaN      0.764918
#
#               pallet_std  customer_num  order_date
# order_num            NaN           NaN    0.999918
# material_num    0.999994      0.908309    0.835337
# order_item           NaN           NaN         NaN
# order_type           NaN      1.000000         NaN
# order_amount         NaN           NaN    0.764918
# pallet_std      1.000000      0.540038         NaN
# customer_num    0.540038      1.000000    0.868886
# order_date           NaN      0.868886    1.000000

# %% [markdown]
# ### eda

# %%
# all sales
ts=df.groupby(["order_date"])["order_amount"].sum()
plt.figure(figsize=(16,8))
plt.title('All sales')
plt.xlabel('Time')
plt.ylabel('Sales')
plt.plot(ts)

# %%
plt.figure(figsize=(16,6))
plt.plot(ts.rolling(window=12,center=False).mean(),label='Rolling Mean');
plt.plot(ts.rolling(window=12,center=False).std(),label='Rolling sd');
plt.legend();

# %% [markdown]
# ### feature engineering

# %%
# these may be useless???
df['order_weekday'] =  df['order_date'].dt.weekday
df['order_month'] = df['order_date'].dt.month
df['order_day'] = df['order_date'].dt.day
df['week'] = df['order_date'].dt.week

# %%
# all sales
ts=df.groupby(["week"])["order_amount"].sum()
plt.figure(figsize=(16,8))
plt.title('All sales')
plt.xlabel('Time')
plt.ylabel('Sales')
plt.plot(ts)

# %%
# geçmişte iptal edilen sipariş var mı
item_nums = df.groupby(['order_num']).agg({'order_amount':'count', 'order_item':'max'}).reset_index()
cancelled_items_exist = item_nums[~(item_nums['order_amount'].values == item_nums['order_item'].values)]['order_num']
cancelled_items_exist

# %%
df.loc[:,'is_cancelled_item_exist'] = 0
df.loc[df['order_num'].isin(cancelled_items_exist), 'is_cancelled_item_exist'] = 1

# %% [markdown]
# ### müşteri ürünü sipariş ettikten sonra ne kadar zaman geçti

# %%
material_order_dates = df.groupby(['customer_num','order_num', 'material_num'])['order_date'].min().reset_index()
material_order_dates['shifted_date'] = material_order_dates.groupby(['customer_num','order_num', 'material_num'])['order_date'].diff()

# %% [markdown]
# ### last 1, 2, 3, 5, 7, 10 orders

# %%
order_amounts = df.groupby(['customer_num', 'material_num','order_num'])['order_amount'].sum().reset_index()
for period in [1,2,3,5,7,10]:
    col_name = 'last_' + str(period) + '_period_sum'
    order_amounts['rolling_sum'] = order_amounts.groupby(['customer_num', 'material_num'])['order_amount'] \
    .rolling(period, min_periods=period).sum().values
    
    order_amounts[col_name] = order_amounts.groupby(['customer_num', 'material_num'])['rolling_sum'].shift(1)
# Out:
# <ipython-input-67-f638bdb1b23e>:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   order_amounts['rolling_sum'] = order_amounts.groupby(['customer_num', 'material_num'])['order_date','order_amount'] \
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-f638bdb1b23e> in <module>
#       3     col_name = 'last_' + str(period) + '_period_sum'
#       4     period = str(period)+'d'
# ----> 5     order_amounts['rolling_sum'] = order_amounts.groupby(['customer_num', 'material_num'])['order_date','order_amount'] \
#       6     .rolling(period).sum().values
#       7
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1601                 stacklevel=2,
#    1602             )
# -> 1603         return super().__getitem__(key)
#    1604
#    1605     def _gotitem(self, key, ndim: int, subset=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     218             if len(self.obj.columns.intersection(key)) != len(key):
#     219                 bad_keys = list(set(key).difference(self.obj.columns))
# --> 220                 raise KeyError(f"Columns not found: {str(bad_keys)[1:-1]}")
#     221             return self._gotitem(list(key), ndim=2)
#     222
#
# KeyError: "Columns not found: 'order_date'"

# %%
order_amounts.isna().sum()/order_amounts.shape[0]

# %%
df = pd.merge(df, order_amounts.drop(['order_amount', 'rolling_sum'], axis=1), on=['customer_num', 'material_num', 'order_num'])

# %% [markdown]
# ### total orders in past 1, 3, 7, 14, 30 days

# %%
df.shape
# Out:
# (256677, 8)

# %%
daily_order_amounts = df.groupby(['customer_num', 'material_num','order_date'])['order_amount'].sum().reset_index()
for period in [1,3,7,14,30]:
    col_name = 'last_' + str(period) + '_day_sum'
    period = str(period)+'d'
    daily_order_amounts['rolling_sum'] = daily_order_amounts.groupby(['customer_num', 'material_num'])[,'order_amount'] \
    .rolling(period, min_periods=period).sum().values
    daily_order_amounts[col_name] = daily_order_amounts.groupby(['customer_num', 'material_num'])['rolling_sum'].shift(1)
# Out:
# <ipython-input-70-bc4148ce9ec7>:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   daily_order_amounts['rolling_sum'] = daily_order_amounts.groupby(['customer_num', 'material_num'])['order_date','order_amount'] \
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-bc4148ce9ec7> in <module>
#       3     col_name = 'last_' + str(period) + '_day_sum'
#       4     period = str(period)+'d'
# ----> 5     daily_order_amounts['rolling_sum'] = daily_order_amounts.groupby(['customer_num', 'material_num'])['order_date','order_amount'] \
#       6     .rolling(period, min_periods=period).sum().values
#       7     daily_order_amounts[col_name] = daily_order_amounts.groupby(['customer_num', 'material_num'])['rolling_sum'].shift(1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in rolling(self, *args, **kwargs)
#    1567         from pandas.core.window import RollingGroupby
#    1568
# -> 1569         return RollingGroupby(self, *args, **kwargs)
#    1570
#    1571     @Substitution(name="groupby")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\window\common.py in __init__(self, obj, *args, **kwargs)
#      57         self._groupby.mutated = True
#      58         self._groupby.grouper.mutated = True
# ---> 59         super().__init__(obj, *args, **kwargs)
#      60
#      61     count = _dispatch("count")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\window\rolling.py in __init__(self, obj, window, min_periods, center, win_type, axis, on, closed, **kwargs)
#      92         self.win_freq = None
#      93         self.axis = obj._get_axis_number(axis) if axis is not None else None
# ---> 94         self.validate()
#      95         self._numba_func_cache: Dict[Optional[str], Callable] = dict()
#      96
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\window\rolling.py in validate(self)
#    1829
#    1830     def validate(self):
# -> 1831         super().validate()
#    1832
#    1833         # we allow rolling on a datetimelike index
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\window\rolling.py in validate(self)
#     115             raise ValueError("center must be a boolean")
#     116         if self.min_periods is not None and not is_integer(self.min_periods):
# --> 117             raise ValueError("min_periods must be an integer")
#     118         if self.closed is not None and self.closed not in [
#     119             "right",
#
# ValueError: min_periods must be an integer

# %%
daily_order_amounts.head(50)
# Out:
#    customer_num material_num order_date  order_amount  rolling_sum  \
# 0       C-10001     10000000 2020-10-30             7          NaN
# 1       C-10001     10000000 2020-10-31             9          NaN
# 2       C-10001     10000000 2020-11-02            22          NaN
# 3       C-10001     10000000 2020-11-03             2          NaN
# 4       C-10001     10000000 2020-11-04             7          NaN
# 5       C-10001     10000000 2020-11-05             4          NaN
# 6       C-10001     10000000 2020-11-06             4          NaN
# 7       C-10001     10000000 2020-11-07            11          NaN
# 8       C-10001     10000000 2020-11-09             9          NaN
# 9       C-10001     10000000 2020-11-10             6          NaN
# 10      C-10001     10000000 2020-11-11             6          NaN
# 11      C-10001     10000000 2020-11-12            12          NaN
# 12      C-10001     10000000 2020-11-13             4          NaN
# 13      C-10001     10000000 2020-11-16             6          NaN
# 14      C-10001     10000000 2020-11-17             1          NaN
# 15      C-10001     10000000 2020-11-18             4          NaN
# 16      C-10001     10000000 2020-11-19             7          NaN
# 17      C-10001     10000000 2020-11-20             4          NaN
# 18      C-10001     10000000 2020-11-21             2          NaN
# 19      C-10001     10000000 2020-11-23             1          NaN
# 20      C-10001     10000000 2020-11-24             3          NaN
# 21      C-10001     10000000 2020-11-25             3          NaN
# 22      C-10001     10000000 2020-11-26             5          NaN
# 23      C-10001     10000000 2020-11-27             7          NaN
# 24      C-10001     10000000 2020-11-28             1          NaN
# 25      C-10001     61000058 2020-01-02             2          NaN
# 26      C-10001     61000058 2020-01-03             3          NaN
# 27      C-10001     61000058 2020-01-06             5          NaN
# 28      C-10001     61000058 2020-01-08             3          NaN
# 29      C-10001     61000058 2020-01-10             3          NaN
# 30      C-10001     61000058 2020-01-13             3          NaN
# 31      C-10001     61000058 2020-01-14             2          NaN
# 32      C-10001     61000058 2020-01-17             4          NaN
# 33      C-10001     61000058 2020-01-20             2          NaN
# 34      C-10001     61000058 2020-01-22             2          NaN
# 35      C-10001     61000058 2020-01-23             1          NaN
# 36      C-10001     61000058 2020-01-24             1          NaN
# 37      C-10001     61000058 2020-01-25             1          NaN
# 38      C-10001     61000058 2020-01-27             2          NaN
# 39      C-10001     61000058 2020-01-28             1          NaN
# 40      C-10001     61000058 2020-01-29             1          NaN
# 41      C-10001     61000058 2020-01-30             6          NaN
# 42      C-10001     61000058 2020-01-31             1          NaN
# 43      C-10001     61000058 2020-02-03             5          NaN
# 44      C-10001     61000058 2020-02-05             3          NaN
# 45      C-10001     61000058 2020-02-06             2          NaN
# 46      C-10001     61000058 2020-02-07             2          NaN
# 47      C-10001     61000058 2020-02-08             1          NaN
# 48      C-10001     61000058 2020-02-10             3          NaN
# 49      C-10001     61000058 2020-02-13             1          NaN
#
#     last_1_day_sum  last_3_day_sum  last_7_day_sum  last_14_day_sum  \
# 0              NaN             NaN             NaN              NaN
# 1              7.0             NaN             NaN              NaN
# 2              9.0             NaN             NaN              NaN
# 3             22.0            38.0             NaN              NaN
# 4              2.0            33.0             NaN              NaN
# 5              7.0            31.0             NaN              NaN
# 6              4.0            13.0             NaN              NaN
# 7              4.0            15.0            55.0              NaN
# 8             11.0            19.0            59.0              NaN
# 9              9.0            24.0            59.0              NaN
# 10             6.0            26.0            43.0              NaN
# 11             6.0            21.0            47.0              NaN
# 12            12.0            24.0            52.0              NaN
# 13             4.0            22.0            52.0              NaN
# 14             6.0            22.0            54.0            109.0
# 15             1.0            11.0            44.0            103.0
# 16             4.0            11.0            39.0             98.0
# 17             7.0            12.0            40.0             83.0
# 18             4.0            15.0            38.0             85.0
# 19             2.0            13.0            28.0             80.0
# 20             1.0             7.0            25.0             77.0
# 21             3.0             6.0            22.0             76.0
# 22             3.0             7.0            24.0             68.0
# 23             5.0            11.0            25.0             64.0
# 24             7.0            15.0            25.0             65.0
# 25             NaN             NaN             NaN              NaN
# 26             2.0             NaN             NaN              NaN
# 27             3.0             NaN             NaN              NaN
# 28             5.0            10.0             NaN              NaN
# 29             3.0            11.0             NaN              NaN
# 30             3.0            11.0             NaN              NaN
# 31             3.0             9.0             NaN              NaN
# 32             2.0             8.0            21.0              NaN
# 33             4.0             9.0            23.0              NaN
# 34             2.0             8.0            22.0              NaN
# 35             2.0             8.0            19.0              NaN
# 36             1.0             5.0            17.0              NaN
# 37             1.0             4.0            15.0              NaN
# 38             1.0             3.0            13.0              NaN
# 39             2.0             4.0            13.0             34.0
# 40             1.0             4.0            10.0             33.0
# 41             1.0             4.0             9.0             31.0
# 42             6.0             8.0            13.0             32.0
# 43             1.0             8.0            13.0             30.0
# 44             5.0            12.0            17.0             32.0
# 45             3.0             9.0            19.0             32.0
# 46             2.0            10.0            19.0             32.0
# 47             2.0             7.0            20.0             30.0
# 48             1.0             5.0            20.0             29.0
# 49             3.0             6.0            17.0             30.0
#
#     last_30_day_sum
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26              NaN
# 27              NaN
# 28              NaN
# 29              NaN
# 30              NaN
# 31              NaN
# 32              NaN
# 33              NaN
# 34              NaN
# 35              NaN
# 36              NaN
# 37              NaN
# 38              NaN
# 39              NaN
# 40              NaN
# 41              NaN
# 42              NaN
# 43              NaN
# 44              NaN
# 45              NaN
# 46              NaN
# 47              NaN
# 48              NaN
# 49              NaN

# %%
error in above cell

# %%
df[(df['material_num']=='61001960')&(df['customer_num']=='C-10008')]
# Out:
#         order_num material_num  order_item           order_type  order_amount  \
# 0        72616887     61001960           1  Müşteri Siparişleri            60
# 19       72616896     61001960           2  Müşteri Siparişleri           250
# 48       72616913     61001960           1  Müşteri Siparişleri            70
# 61       72616922     61001960           2  Müşteri Siparişleri            70
# 1401     72617187     61001960           1  Müşteri Siparişleri            20
# ...           ...          ...         ...                  ...           ...
# 255485   72665615     61001960           1  Müşteri Siparişleri            70
# 255490   72665618     61001960           1  Müşteri Siparişleri           140
# 255511   72665627     61001960           2  Müşteri Siparişleri           140
# 255513   72665628     61001960           1  Müşteri Siparişleri            70
# 256591   72665938     61001960           1  Müşteri Siparişleri            70
#
#         pallet_std customer_num order_date  order_weekday  order_month  \
# 0              228      C-10008 2020-01-02              3            1
# 19             228      C-10008 2020-01-02              3            1
# 48             228      C-10008 2020-01-02              3            1
# 61             228      C-10008 2020-01-02              3            1
# 1401           228      C-10008 2020-01-03              4            1
# ...            ...          ...        ...            ...          ...
# 255485         228      C-10008 2020-12-22              1           12
# 255490         228      C-10008 2020-12-22              1           12
# 255511         228      C-10008 2020-12-22              1           12
# 255513         228      C-10008 2020-12-22              1           12
# 256591         228      C-10008 2020-12-23              2           12
#
#         order_day  week
# 0               2     1
# 19              2     1
# 48              2     1
# 61              2     1
# 1401            3     1
# ...           ...   ...
# 255485         22    52
# 255490         22    52
# 255511         22    52
# 255513         22    52
# 256591         23    52
#
# [270 rows x 12 columns]

# %%
df[(df['material_num']=='61001960')]['customer_num'].value_counts()
# Out:
# C-10008    270
# C-10059    244
# C-10101     88
# C-10064     86
# C-10044     86
#           ...
# C-10273      1
# C-10270      1
# C-10042      1
# C-10276      1
# C-10283      1
# Name: customer_num, Length: 152, dtype: int64

# %%
daily_order_amounts[(daily_order_amounts['material_num']=='61001960')&(daily_order_amounts['customer_num']=='C-10008')].head(50)

# %%
daily_order_amounts.head(50)
# Out:
#    order_date customer_num material_num  order_amount  rolling_sum  \
# 0  2020-01-02      C-10001     61000058             2          NaN
# 1  2020-01-02      C-10001     61000192             2          NaN
# 2  2020-01-02      C-10001     61000978             2          NaN
# 3  2020-01-02      C-10001     61003229             2          NaN
# 4  2020-01-02      C-10001     61003793             8          NaN
# 5  2020-01-02      C-10001     CN01148A             3          NaN
# 6  2020-01-02      C-10001     CN01149A             7          NaN
# 7  2020-01-02      C-10001     CN04979A            35          NaN
# 8  2020-01-02      C-10001     CN05798A             5          NaN
# 9  2020-01-02      C-10001     CN05842A            31          NaN
# 10 2020-01-02      C-10001     CN05907A             1          NaN
# 11 2020-01-02      C-10001     CN06158A             3          NaN
# 12 2020-01-02      C-10001     CN06538A             1          NaN
# 13 2020-01-02      C-10001     CN06776A             3          NaN
# 14 2020-01-02      C-10001     CN06795A            31          NaN
# 15 2020-01-02      C-10001     CN07128A             2          NaN
# 16 2020-01-02      C-10001     CN07546A             5          NaN
# 17 2020-01-02      C-10001     CN07611A            31          NaN
# 18 2020-01-02      C-10001     FCN01692            24          NaN
# 19 2020-01-02      C-10001     FCN01698            57          NaN
# 20 2020-01-02      C-10001     FCN01816             5          NaN
# 21 2020-01-02      C-10001     FCN01872            31          NaN
# 22 2020-01-02      C-10001     FTP00013             1          NaN
# 23 2020-01-02      C-10001     PL05157A            11          NaN
# 24 2020-01-02      C-10001     PL05158A            14          NaN
# 25 2020-01-02      C-10001     PL05174A             9          NaN
# 26 2020-01-02      C-10001     PL06586A            11          NaN
# 27 2020-01-02      C-10001     PL06758A             8          NaN
# 28 2020-01-02      C-10001     PL06760A            13          NaN
# 29 2020-01-02      C-10001     PL06762A            29          NaN
# 30 2020-01-02      C-10001     PL06763A             3          NaN
# 31 2020-01-02      C-10001     PL07760A             6          NaN
# 32 2020-01-02      C-10001     PL07785B             2          NaN
# 33 2020-01-02      C-10001     PL07811B            23          NaN
# 34 2020-01-02      C-10001     PL08094A            15          NaN
# 35 2020-01-02      C-10001     PL08098A            23          NaN
# 36 2020-01-02      C-10001     PL08279A            16          NaN
# 37 2020-01-02      C-10001     TR00176D             4          NaN
# 38 2020-01-02      C-10001     TR00191C            11          NaN
# 39 2020-01-02      C-10001     TR01064B            11          NaN
# 40 2020-01-02      C-10001     TR01066B            11          NaN
# 41 2020-01-02      C-10001     TR01086A            10          NaN
# 42 2020-01-02      C-10001     TR01164A             4          NaN
# 43 2020-01-02      C-10001     TR01178A             1          NaN
# 44 2020-01-02      C-10001     TR01184A             1          NaN
# 45 2020-01-02      C-10001     TR01499C             2          NaN
# 46 2020-01-02      C-10001     TR01655A             5          NaN
# 47 2020-01-02      C-10001     TR01659C             5          NaN
# 48 2020-01-02      C-10001     TR01660C             2          NaN
# 49 2020-01-02      C-10001     TR01661A            10          NaN
#
#     last_1_day_sum  last_3_day_sum  last_7_day_sum  last_14_day_sum  \
# 0              NaN             NaN             NaN              NaN
# 1              NaN             NaN             NaN              NaN
# 2              NaN             NaN             NaN              NaN
# 3              NaN             NaN             NaN              NaN
# 4              NaN             NaN             NaN              NaN
# 5              NaN             NaN             NaN              NaN
# 6              NaN             NaN             NaN              NaN
# 7              NaN             NaN             NaN              NaN
# 8              NaN             NaN             NaN              NaN
# 9              NaN             NaN             NaN              NaN
# 10             NaN             NaN             NaN              NaN
# 11             NaN             NaN             NaN              NaN
# 12             NaN             NaN             NaN              NaN
# 13             NaN             NaN             NaN              NaN
# 14             NaN             NaN             NaN              NaN
# 15             NaN             NaN             NaN              NaN
# 16             NaN             NaN             NaN              NaN
# 17             NaN             NaN             NaN              NaN
# 18             NaN             NaN             NaN              NaN
# 19             NaN             NaN             NaN              NaN
# 20             NaN             NaN             NaN              NaN
# 21             NaN             NaN             NaN              NaN
# 22             NaN             NaN             NaN              NaN
# 23             NaN             NaN             NaN              NaN
# 24             NaN             NaN             NaN              NaN
# 25             NaN             NaN             NaN              NaN
# 26             NaN             NaN             NaN              NaN
# 27             NaN             NaN             NaN              NaN
# 28             NaN             NaN             NaN              NaN
# 29             NaN             NaN             NaN              NaN
# 30             NaN             NaN             NaN              NaN
# 31             NaN             NaN             NaN              NaN
# 32             NaN             NaN             NaN              NaN
# 33             NaN             NaN             NaN              NaN
# 34             NaN             NaN             NaN              NaN
# 35             NaN             NaN             NaN              NaN
# 36             NaN             NaN             NaN              NaN
# 37             NaN             NaN             NaN              NaN
# 38             NaN             NaN             NaN              NaN
# 39             NaN             NaN             NaN              NaN
# 40             NaN             NaN             NaN              NaN
# 41             NaN             NaN             NaN              NaN
# 42             NaN             NaN             NaN              NaN
# 43             NaN             NaN             NaN              NaN
# 44             NaN             NaN             NaN              NaN
# 45             NaN             NaN             NaN              NaN
# 46             NaN             NaN             NaN              NaN
# 47             NaN             NaN             NaN              NaN
# 48             NaN             NaN             NaN              NaN
# 49             NaN             NaN             NaN              NaN
#
#     last_30_day_sum
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26              NaN
# 27              NaN
# 28              NaN
# 29              NaN
# 30              NaN
# 31              NaN
# 32              NaN
# 33              NaN
# 34              NaN
# 35              NaN
# 36              NaN
# 37              NaN
# 38              NaN
# 39              NaN
# 40              NaN
# 41              NaN
# 42              NaN
# 43              NaN
# 44              NaN
# 45              NaN
# 46              NaN
# 47              NaN
# 48              NaN
# 49              NaN

# %%
plt.figure(figsize=(16,6))
plt.plot(ts.rolling(window=12,center=False).mean(),label='Rolling Mean');
plt.legend();

# %% [markdown]
# ### order_item numbers in an order

# %%
item_counts = df.groupby(['order_num'])['order_item'].count().reset_index()
item_counts.columns = ['order_num', 'num_order_item']
df = pd.merge(df, item_counts, on=['order_num'])

# %% [markdown]
# ### modelling

# %%
drops = ['order_num', 'order_date']
label = ['order_amount']
categorical = ['material_num', 'order_item', 'order_type', 'pallet_std', 'customer_num',
               'order_weekday', 'order_month', 'order_day', 'is_cancelled_item_exist']
numerical = ['last_1_period_sum', 'last_2_period_sum', 'last_3_period_sum',
            'last_5_period_sum', 'last_7_period_sum', 'last_10_period_sum', 'num_order_item']

# %%
def create_pipeline_without_model(reg_name, reg_object):
    
    numeric_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='constant', fill_value=0.0)),
        ('scaler', StandardScaler())])
    
    categorical_transformer = Pipeline(steps=[
        ('one-hot', OneHotEncoder(handle_unknown='ignore'))])


    preprocessor = ColumnTransformer(
                                    transformers=[
                                                  ('num1', numeric_transformer, numerical),       
                                                  ('cat_str1', categorical_transformer, categorical),
                                                  ])

    pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                               (reg_name, reg_object)])
    
    return pipeline

# %%
y = df[label]
X = df[categorical+numerical]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1)

pipe1 = create_pipeline_without_model('regressor', XGBRegressor())
pipe1.fit(X_train, y_train)
preds_train = pipe1.predict(X_train)
preds_test = pipe1.predict(X_test)

print('Train scores: ')
print("R2 score:{}, RMSE:{}".format(r2_score(y_train, preds_train), rmse(preds_train, y_train)))
print('-----')
print('Test scores: ')
print("R2 score:{}, RMSE:{}".format(r2_score(y_test, preds_test), rmse(preds_test, y_test)))

# %%
def evaluate_model_with_CV(X, y, model):
    cv = KFold(n_splits=5, shuffle=True, random_state=1)
    scores = cross_validate(model, X, y, scoring=['neg_root_mean_squared_error', 'r2'], n_jobs=-1, 
                        return_estimator=True, return_train_score=True, cv=cv)
    # ['fit_time', 'score_time', 'estimator', 'test_neg_root_mean_squared_error', 
    # 'train_neg_root_mean_squared_error', 'test_r2', 'train_r2']

    return scores

# %%
def print_metrics(y_pred, y_test, model):
    print("Model results: ", type(model).__name__)
    print(classification_report(y_test, y_pred))
    print("Confusion matrix:")
    cm = confusion_matrix(y_test,y_pred, labels= model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels= model.classes_)
    disp.plot()

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet, BayesianRidge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR, LinearSVR
from xgboost import XGBRegressor
from sklearn.kernel_ridge import KernelRidge

# %%
regressors = [
    ("XGBRegressor", XGBRegressor()),
    ("SVR", SVR()),
    ("LinearSVR", LinearSVR()),
    ("KernelRidge", KernelRidge()),
    ("LinearRegression", LinearRegression()),
    ("Ridge",Ridge()),
    ("Lasso",Lasso()),
    ("BayesianRidge", BayesianRidge()),
    ("ElasticNet", ElasticNet()),
]

# %%
y = df[label]
X = df[categorical+numerical]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1)

pipe1 = create_pipeline_without_model('regressor', LinearRegression())
pipe1.fit(X_train, y_train)
preds_train = pipe1.predict(X_train)
preds_test = pipe1.predict(X_test)

print('Train scores: ')
print("R2 score:{}, RMSE:{}".format(r2_score(y_train, preds_train), rmse(preds_train, y_train)))
print('-----')
print('Test scores: ')
print("R2 score:{}, RMSE:{}".format(r2_score(y_test, preds_test), rmse(preds_test, y_test)))

# %%
random_state = 1
RMSE_train_mean = []
RMSE_train_std = []
RMSE_test_mean = []
RMSE_test_std = []
R2_train_mean = []
R2_train_std = []
R2_test_mean = []
R2_test_std = []
names = []
TIME = []

for name, regressor in tqdm(regressors):
    
    pipe = create_pipeline_without_model(name, regressor)
    results = evaluate_model_with_CV(X, y, pipe)
                        
    names.append(name)
    RMSE_train_mean.append(results['train_neg_root_mean_squared_error'].mean())
    RMSE_train_std.append(results['train_neg_root_mean_squared_error'].std())
    RMSE_test_mean.append(results['test_neg_root_mean_squared_error'].mean())
    RMSE_test_std.append(results['test_neg_root_mean_squared_error'].std())
    R2_train_mean.append(results['train_r2'].mean())
    R2_train_std.append(results['train_r2'].std())
    R2_test_mean.append(results['test_r2'].mean())
    R2_test_std.append(results['test_r2'].std())
    TIME.append(results['fit_time'].mean())

    
scores = pd.DataFrame({ "Model": names,
                        "RMSE_train_mean": RMSE_train_mean,
                        "RMSE_train_std": RMSE_train_std,
                        "RMSE_test_mean": RMSE_test_mean,
                        "RMSE_test_std": RMSE_test_std,
                       
                        "R2_train_mean": R2_train_mean,
                        "R2_train_std": R2_train_std,
                        "R2_test_mean": R2_test_mean,
                        "R2_test_std": R2_test_std,
                        "Time Taken": TIME, })

# %%
RMSE_train_mean

# %%
order_amounts

# %%
order_amounts.head(50)

# %%
df.rolling(2).sum()

# %%
item_nums

# %%
df[df['order_num'].isin(cancelled_items_exist)]
